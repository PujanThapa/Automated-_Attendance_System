# %%
import cv2 
import tensorflow as tf
import numpy as np
from mtcnn.mtcnn import MTCNN
from keras_facenet.__init__ import FaceNet
import matplotlib.pyplot as plt

# %%
import time
import gspread
from google.oauth2 import service_account
from googleapiclient.discovery import build

# %%
from scipy.spatial.distance import cosine
import time

# %%
detector=MTCNN()
def face_extractor(image):
    img=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
    faces=detector.detect_faces(img)
    face_array=[]
    X=[]
    Y=[]
    W=[]
    H=[]
    for i in faces:
        x,y,w,h=i['box']
        x=abs(x)
        y=abs(y)
        single_face=img[y:y+h,x:x+w]
        single_face=cv2.resize(single_face,(160,160))
        face_array.append(single_face)
        X.append(x)
        Y.append(y)
        W.append(w)
        H.append(h)
      
    return np.asarray(face_array),X,Y,W,H
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 detector=MTCNN()
#       2 def face_extractor(image):
#       3     img=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\mtcnn\mtcnn.py:81, in MTCNN.__init__(self, weights_file, min_face_size, steps_threshold, scale_factor)
#      78     steps_threshold = [0.6, 0.7, 0.7]
#      80 if weights_file is None:
# ---> 81     weights_file = pkg_resources.resource_stream('mtcnn', 'data/mtcnn_weights.npy')
#      83 self._min_face_size = min_face_size
#      84 self._steps_threshold = steps_threshold
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pkg_resources\__init__.py:1160, in ResourceManager.resource_stream(self, package_or_requirement, resource_name)
#    1158 def resource_stream(self, package_or_requirement, resource_name):
#    1159     """Return a readable file-like object for specified resource"""
# -> 1160     return get_provider(package_or_requirement).get_resource_stream(
#    1161         self, resource_name
#    1162     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pkg_resources\__init__.py:1632, in DefaultProvider.get_resource_stream(self, manager, resource_name)
#    1631 def get_resource_stream(self, manager, resource_name):
# -> 1632     return open(self._fn(self.module_path, resource_name), 'rb')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\hp\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\mtcnn\\data\\mtcnn_weights.npy'

# %%
embedder=FaceNet(key='20170511-185253',use_prebuilt=True)
def get_embedding(face_img):
    face_img = face_img.astype('float32')
    mean,std=face_img.mean(),face_img.std()
    face_img=(face_img-mean)/std
    face_img = np.expand_dims(face_img, axis=0)
    yhat= embedder.embeddings(face_img)
    return yhat[0]

# %%
x=np.load('./faces_embeddings_new_augmented.npz')
embedding_x = x['arr_0']
label = x['arr_1']

# %%
def attendance(embedding_test,threshold=0.75):
  max_similarity = -float('inf')
  recognized_person = None
  for embedding,person in zip(embedding_x,label):
    similarity=1-cosine(embedding_test,embedding)
    if similarity > max_similarity:
        max_similarity = similarity
        recognized_person = person     

  if max_similarity > threshold:
    return recognized_person
  else:
    return None

# %%
SCOPE=['https://www.googleapis.com/auth/spreadsheets']
filename='./keys.json'
credentials=None
credentials=service_account.Credentials.from_service_account_file(filename,scopes=SCOPE)

service_sheets=build('sheets','v4',credentials=credentials)
sheet_id='1rFalylfxELomgYtZ6CuvgKDHGk8F-KPCIzlnl_uIibI'
sheet_name='Sheet1!'


def update_attendance(name):
    current_time = time.strftime("%H:%M:%S", time.localtime())
    current_date = time.strftime("%Y-%m-%d", time.localtime())
    
    a=2
    for i in name:
        values=((i,current_date,current_time),)
        cell_range=f'A{a}:C{a}'
        v_body={
        'majorDimension':'ROWS',
        'values':values}
        
        service_sheets.spreadsheets().values().update(
            spreadsheetId=sheet_id,
            valueInputOption='USER_ENTERED',
            range=sheet_name + cell_range,
            body=v_body
        ).execute()
        a+=1

# %%
att_time=["07:15:00","08:55:00","10:35:00","11:25:00"]
current_time = time.strftime("%H:%M:%S", time.localtime())
cap = cv2.VideoCapture(0)
if cap.isOpened():
  print("camera opened successfully!")
else:
  print("NO")

desired_width = 1280
desired_height = 720

cap.set(3, desired_width)
cap.set(4, desired_height)

start_time=time.time()

while True:
    ret,frame=cap.read()

    presence=[]
    if ret:
        faces,x,y,w,h=face_extractor(frame)
        
        for i in range(len(faces)):
            cv2.rectangle(frame, (x[i], y[i]), (x[i]+w[i], y[i]+h[i]), (255,0,0), 3)
        
        for a in faces:
            face_embedding=get_embedding(a)
            recog=attendance(face_embedding)
            
            if recog in label:
                presence.append(recog)
                
                
            else:
                presence.append("Unknown")
                
        
        end_time=time.time()
        duration=end_time-start_time
        print(f"Time taken: {duration} sec")
        
        print(f"{presence}'s face is detected")
        for i in range(len(faces)):
            cv2.putText(frame, presence[i], (x[i], y[i]-10), cv2.FONT_HERSHEY_SIMPLEX, 1, (255,0,255), 2, cv2.LINE_AA)
        if duration>=4:
            
            update_attendance(presence)
            presence=[]
            
            pass
        
        start_time=time.time()
        plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
        plt.axis('off')
        plt.show()
        
        if cv2.waitKey(1000) & 0xFF == ord('q'):
            break
        
        

        
        
            

cap.release()
cv2.destroyAllWindows()
# Out:
# camera opened successfully!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 828ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 609ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 351ms/step
# WARNING:tensorflow:5 out of the last 14 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0xfffef46f49d0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 16s 16s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step
# Time taken: 36.510136127471924 sec
# ['Unknown', 'Unknown', 'Unknown', 'Unknown', 'pujan', 'mohan', 'Unknown', 'Unknown', 'ranjan']'s face is detected
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step
# Time taken: 17.08863663673401 sec
# ['Unknown', 'mohan', 'Unknown', 'Unknown', 'pujan', 'Unknown', 'Unknown', 'ranjan', 'Unknown']'s face is detected
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step
# Time taken: 17.67330050468445 sec
# ['Unknown', 'prabhat', 'Unknown', 'mohan', 'Unknown', 'Unknown', 'ranjan', 'pujan', 'Unknown']'s face is detected
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step
# Time taken: 17.945079803466797 sec
# ['Unknown', 'Unknown', 'Unknown', 'mohan', 'pujan', 'Unknown', 'Unknown', 'ranjan', 'Unknown']'s face is detected
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step
# Time taken: 16.820119857788086 sec
# ['Unknown', 'mohan', 'Unknown', 'Unknown', 'Unknown', 'ranjan', 'pujan', 'Unknown', 'Unknown']'s face is detected
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step
# Time taken: 15.121855974197388 sec
# ['prabhat', 'Unknown', 'ranjan', 'pujan', 'Unknown', 'Unknown', 'Unknown']'s face is detected
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step
# Time taken: 17.429920434951782 sec
# ['Unknown', 'prabhat', 'Unknown', 'Unknown', 'Unknown', 'Unknown', 'Unknown', 'Unknown', 'Unknown']'s face is detected
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 387ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step
# Time taken: 7.9535064697265625 sec
# ['pujan', 'prabhat']'s face is detected
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step
# Time taken: 5.539066791534424 sec
# []'s face is detected
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Time taken: 5.333904981613159 sec
# []'s face is detected
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step
# Time taken: 6.951145887374878 sec
# ['Unknown']'s face is detected
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step
# Time taken: 7.279993772506714 sec
# ['pujan']'s face is detected
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# Time taken: 5.64351487159729 sec
# []'s face is detected
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 397ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# Time taken: 5.945710897445679 sec
# []'s face is detected
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 389ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# /usr/local/share/pynq-venv/lib/python3.10/site-packages/mtcnn/mtcnn.py:206: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if method is 'Min':
# /usr/local/share/pynq-venv/lib/python3.10/site-packages/mtcnn/mtcnn.py:206: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if method is 'Min':
# /usr/local/share/pynq-venv/lib/python3.10/site-packages/mtcnn/mtcnn.py:206: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if method is 'Min':
# /usr/local/share/pynq-venv/lib/python3.10/site-packages/mtcnn/mtcnn.py:206: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if method is 'Min':
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [9], in <cell line: 17>()
#      20 presence=[]
#      21 if ret:
# ---> 22     faces,x,y,w,h=face_extractor(frame)
#      24     for i in range(len(faces)):
#      25         cv2.rectangle(frame, (x[i], y[i]), (x[i]+w[i], y[i]+h[i]), (255,0,0), 3)
#
# Input In [4], in face_extractor(image)
#       2 def face_extractor(image):
#       3     img=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
# ----> 4     faces=detector.detect_faces(img)
#       5     face_array=[]
#       6     X=[]
#
# File /usr/local/share/pynq-venv/lib/python3.10/site-packages/mtcnn/mtcnn.py:300, in MTCNN.detect_faces(self, img)
#     298 # We pipe here each of the stages
#     299 for stage in stages:
# --> 300     result = stage(img, result[0], result[1])
#     302 [total_boxes, points] = result
#     304 bounding_boxes = []
#
# File /usr/local/share/pynq-venv/lib/python3.10/site-packages/mtcnn/mtcnn.py:342, in MTCNN.__stage1(self, image, scales, stage_status)
#     339 img_x = np.expand_dims(scaled_image, 0)
#     340 img_y = np.transpose(img_x, (0, 2, 1, 3))
# --> 342 out = self._pnet.predict(img_y)
#     344 out0 = np.transpose(out[0], (0, 2, 1, 3))
#     345 out1 = np.transpose(out[1], (0, 2, 1, 3))
#
# File /usr/local/share/pynq-venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/share/pynq-venv/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:446, in TensorFlowTrainer.predict(self, x, batch_size, verbose, steps, callbacks)
#     441 @traceback_utils.filter_traceback
#     442 def predict(
#     443     self, x, batch_size=None, verbose="auto", steps=None, callbacks=None
#     444 ):
#     445     # Create an iterator that yields batches of input data.
# --> 446     epoch_iterator = TFEpochIterator(
#     447         x=x,
#     448         batch_size=batch_size,
#     449         steps_per_epoch=steps,
#     450         shuffle=False,
#     451         distribute_strategy=self.distribute_strategy,
#     452         steps_per_execution=self.steps_per_execution,
#     453     )
#     455     # Container that configures and calls callbacks.
#     456     if not isinstance(callbacks, callbacks_module.CallbackList):
#
# File /usr/local/share/pynq-venv/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:629, in TFEpochIterator.__init__(self, distribute_strategy, *args, **kwargs)
#     627 super().__init__(*args, **kwargs)
#     628 self._distribute_strategy = distribute_strategy
# --> 629 dataset = self._get_iterator()
#     630 if not isinstance(dataset, tf.distribute.DistributedDataset):
#     631     dataset = self._distribute_strategy.experimental_distribute_dataset(
#     632         dataset
#     633     )
#
# File /usr/local/share/pynq-venv/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:638, in TFEpochIterator._get_iterator(self)
#     637 def _get_iterator(self):
# --> 638     return self.data_adapter.get_tf_dataset()
#
# File /usr/local/share/pynq-venv/lib/python3.10/site-packages/keras/src/trainers/data_adapters/array_data_adapter.py:236, in ArrayDataAdapter.get_tf_dataset(self)
#     233 if shuffle == "batch":
#     234     indices_dataset = indices_dataset.map(tf.random.shuffle)
# --> 236 dataset = slice_inputs(indices_dataset, self._inputs)
#     238 options = tf.data.Options()
#     239 options.experimental_distribute.auto_shard_policy = (
#     240     tf.data.experimental.AutoShardPolicy.DATA
#     241 )
#
# File /usr/local/share/pynq-venv/lib/python3.10/site-packages/keras/src/trainers/data_adapters/array_data_adapter.py:191, in ArrayDataAdapter.get_tf_dataset.<locals>.slice_inputs(indices_dataset, inputs)
#     176 def slice_inputs(indices_dataset, inputs):
#     177     """Slice inputs into a Dataset of batches.
#     178
#     179     Given a Dataset of batch indices and the unsliced inputs,
#    (...)
#     189         A Dataset of input batches matching the batch indices.
#     190     """
# --> 191     inputs = array_slicing.convert_to_sliceable(
#     192         self._inputs, target_backend="tensorflow"
#     193     )
#     194     inputs = tree.lists_to_tuples(inputs)
#     196     dataset = tf.data.Dataset.zip(
#     197         (indices_dataset, tf.data.Dataset.from_tensors(inputs).repeat())
#     198     )
#
# File /usr/local/share/pynq-venv/lib/python3.10/site-packages/keras/src/trainers/data_adapters/array_slicing.py:450, in convert_to_sliceable(arrays, target_backend)
#     446         sliceable_class = NumpySliceable
#     448     return sliceable_class(x)
# --> 450 return tree.map_structure(convert_single_array, arrays)
#
# File /usr/local/share/pynq-venv/lib/python3.10/site-packages/keras/src/tree/tree_api.py:148, in map_structure(func, *structures)
#     124 @keras_export("keras.tree.map_structure")
#     125 def map_structure(func, *structures):
#     126     """Maps `func` through given structures.
#     127
#     128     Examples:
#    (...)
#     146         A new structure with the same layout as the given ones.
#     147     """
# --> 148     return tree_impl.map_structure(func, *structures)
#
# File /usr/local/share/pynq-venv/lib/python3.10/site-packages/keras/src/tree/optree_impl.py:79, in map_structure(func, *structures)
#      77 for other in structures[1:]:
#      78     assert_same_structure(structures[0], other, check_types=False)
# ---> 79 return optree.tree_map(
#      80     func, *structures, none_is_leaf=True, namespace="keras"
#      81 )
#
# File /usr/local/share/pynq-venv/lib/python3.10/site-packages/optree/ops.py:594, in tree_map(func, tree, is_leaf, none_is_leaf, namespace, *rests)
#     592 leaves, treespec = _C.flatten(tree, is_leaf, none_is_leaf, namespace)
#     593 flat_args = [leaves] + [treespec.flatten_up_to(r) for r in rests]
# --> 594 return treespec.unflatten(map(func, *flat_args))
#
# File /usr/local/share/pynq-venv/lib/python3.10/site-packages/keras/src/trainers/data_adapters/array_slicing.py:423, in convert_to_sliceable.<locals>.convert_single_array(x)
#     421         cast_dtype = backend.floatx()
#     422 else:
# --> 423     if is_non_floatx_float(x.dtype):
#     424         cast_dtype = backend.floatx()
#     426 if cast_dtype is not None:
#
# File /usr/local/share/pynq-venv/lib/python3.10/site-packages/keras/src/trainers/data_adapters/array_slicing.py:414, in convert_to_sliceable.<locals>.convert_single_array.<locals>.is_non_floatx_float(dtype)
#     411 def is_non_floatx_float(dtype):
#     412     return (
#     413         not dtype == object
# --> 414         and backend.is_float_dtype(dtype)
#     415         and not backend.standardize_dtype(dtype) == backend.floatx()
#     416     )
#
# File /usr/local/share/pynq-venv/lib/python3.10/site-packages/keras/src/backend/common/variables.py:574, in is_float_dtype(dtype)
#     572 @keras_export("keras.backend.is_float_dtype")
#     573 def is_float_dtype(dtype):
# --> 574     dtype = standardize_dtype(dtype)
#     575     return dtype.startswith("float") or dtype.startswith("bfloat")
#
# File /usr/local/share/pynq-venv/lib/python3.10/site-packages/keras/src/backend/common/variables.py:511, in standardize_dtype(dtype)
#     509     return config.floatx()
#     510 dtype = dtypes.PYTHON_DTYPES_MAP.get(dtype, dtype)
# --> 511 if hasattr(dtype, "name"):
#     512     dtype = dtype.name
#     513 elif hasattr(dtype, "__str__") and (
#     514     "torch" in str(dtype) or "jax.numpy" in str(dtype)
#     515 ):
#
# File /usr/local/share/pynq-venv/lib/python3.10/site-packages/numpy/core/_dtype.py:346, in _name_get(dtype)
#     342     else:
#     343         return True
# --> 346 def _name_get(dtype):
#     347     # provides dtype.name.__get__, documented as returning a "bit name"
#     349     if dtype.isbuiltin == 2:
#     350         # user dtypes don't promise to do anything special
#     351         return dtype.type.__name__
#
# KeyboardInterrupt:
